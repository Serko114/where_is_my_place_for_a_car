# %%
class MyClass:
    """Простой пример класса"""
    i = 12345
    def __init__(self, s, d):
        self.s = s
        self.d = d
    def f(self):
        return f'привет, мир {self.s + self.d}'

# %%
x = MyClass(100,1000)

# %%
x.f()
# Out:
# 'привет, мир 1100'

# %%
x.i
# Out:
# 12345
